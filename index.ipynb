# %% [markdown]
# # ARMA Models in StatsModels - Lab
#
# ## Introduction
#
# In this lesson, you'll fit an ARMA model using `statsmodels` to a real-world dataset.
#
#
# ## Objectives
#
# In this lab you will:
#
# - Decide the optimal parameters for an ARMA model by plotting ACF and PACF and interpreting them
# - Fit an ARMA model using StatsModels
#
# ## Dataset
#
# Run the cell below to import the dataset containing the historical running times for the men's 400m in the Olympic games.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning

warnings.simplefilter("ignore", ConvergenceWarning)

data = pd.read_csv("winning_400m.csv")
data["year"] = pd.to_datetime(data["year"].astype(str))
data.set_index("year", inplace=True)
data.index = data.index.to_period("Y")

# %%
# Preview the dataset
data
# Out:
#       winning_times
# year
# 1900           49.4
# 1904           49.2
# 1908           50.0
# 1912           48.2
# 1920           49.6
# 1924           47.6
# 1928           47.8
# 1932           46.2
# 1936           46.5
# 1948           46.2
# 1952           45.9
# 1956           46.7
# 1960           44.9
# 1964           45.1
# 1968           43.8
# 1972           44.7
# 1976           44.3
# 1980           44.6
# 1984           44.3
# 1988           43.9
# 1992           43.5
# 1996           43.5

# %% [markdown]
# Plot this time series data.

# %%
# Plot the time series
data.plot(figsize=(14,8))
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# If you plotted the time series correctly, you should notice that it is not stationary. So, difference the data to get a stationary time series. Make sure to remove the missing values.

# %%
# Difference the time series
data_diff = data.diff(periods=1)
data_diff.dropna(inplace=True)
data_diff
# Out:
#       winning_times
# year
# 1904           -0.2
# 1908            0.8
# 1912           -1.8
# 1920            1.4
# 1924           -2.0
# 1928            0.2
# 1932           -1.6
# 1936            0.3
# 1948           -0.3
# 1952           -0.3
# 1956            0.8
# 1960           -1.8
# 1964            0.2
# 1968           -1.3
# 1972            0.9
# 1976           -0.4
# 1980            0.3
# 1984           -0.3
# 1988           -0.4
# 1992           -0.4
# 1996            0.0

# %% [markdown]
# Use `statsmodels` to plot the ACF and PACF of this differenced time series.

# %%
# Plot the ACF
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

fig,ax = plt.subplots(figsize=(14,8))
plot_acf(data_diff, ax=ax, lags= 10);

# %%
# Plot the PACF

fig, ax = plt.subplots(figsize=(14,8))

plot_pacf(data_diff, ax=ax, lags= 10);

# %% [markdown]
# Based on the ACF and PACF, fit an ARMA model with the right orders for AR and MA. Feel free to try different models and compare AIC and BIC values, as well as significance values for the parameter estimates.

# %%
from statsmodels.tsa.arima.model import ARIMA
mod_arma = ARIMA(data_diff, order=(1,0,0))

# %%
model = mod_arma.fit()

# %%
print(model.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:          winning_times   No. Observations:                   21
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                 -20.054
# Date:                Thu, 17 Oct 2024   AIC                             46.107
# Time:                        09:56:45   BIC                             49.241
# Sample:                    12-31-1904   HQIC                            46.787
#                          - 12-31-1996
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2885      0.081     -3.559      0.000      -0.447      -0.130
# ar.L1         -0.7186      0.144     -5.005      0.000      -1.000      -0.437
# sigma2         0.3819      0.180      2.121      0.034       0.029       0.735
# ...

# %%
# Fit ARMA(1,1) model
model_arma_1_1 = ARIMA(data_diff, order=(1,0,0)).fit()

# Fit ARMA(2,1) model
model_arma_2_1 = ARIMA(data_diff, order=(2,0,1)).fit()

# Fit ARMA(1,2) model
model_arma_1_2 = ARIMA(data_diff, order=(1,0,2)).fit()

# Compare AIC and BIC values
print(f'ARMA(1,0) AIC: {model_arma_1_1.aic}, BIC: {model_arma_1_1.bic}')
print(f'ARMA(2,1) AIC: {model_arma_2_1.aic}, BIC: {model_arma_2_1.bic}')
print(f'ARMA(1,2) AIC: {model_arma_1_2.aic}, BIC: {model_arma_1_2.bic}')
# Out:
# ARMA(1,0) AIC: 46.10733707941738, BIC: 49.240904392587645
# ARMA(2,1) AIC: 49.861773637672066, BIC: 55.08438582628918
# ARMA(1,2) AIC: 48.151706360301226, BIC: 53.37431854891834

# %% [markdown]
# ## What is your final model? Why did you pick this model?

# %%
# Your comments here

"""
ARMA(1,0), ARMA(2,2) and ARMA(2,1) all seem to have decent fits with significant parameters. 
Depending on whether you pick AIC or BIC as a model selection criterion, 
your result may vary. In this situation, you'd generally go for a model with fewer parameters, 
so ARMA(1,0) seems fine. Note that we have a relatively short time series, 
which can lead to a more difficult model selection process.
"""

# %% [markdown]
# ## Summary
#
# Well done. In addition to manipulating and visualizing time series data, you now know how to create a stationary time series and fit ARMA models.
